# %%
#Download data by using twint
#Data on Berkshire hathaway before pandemic were downloaded by comands typed in terminal:
#twint -s "Berkshire hataway" --csv -o BH_tweets_before_pandemic_part1.csv --since 2018-07-01 --until 2018-10-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_before_pandemic_part2.csv --since 2018-04-01 --until 2018-07-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_before_pandemic_part3.csv --since 2018-01-01 --until 2018-04-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_before_pandemic_part4.csv --since 2017-10-01 --until 2018-01-01

#during pandemic:
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_pandemic_part1.csv --since 2020-07-01 --until 2020-10-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_pandemic_part2.csv --since 2020-04-01 --until 2020-07-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_pandemic_part3.csv --since 2020-01-01 --until 2020-04-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_pandemic_part4.csv --since 2019-10-01 --until 2020-01-01

#during war:
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part1.csv --since 2022-03-08 --until 2022-04-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part2.csv --since 2022-02-23 --until 2022-03-09
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part3.csv --since 2022-02-23 --until "2022-02-23 11:05:00"
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part4.csv --since 2021-11-23 --until "2022-02-23 06:17:00"
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part5.csv --since 2021-09-01 --until 2021-11-24
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part6.csv --since 2021-06-01 --until 2021-09-01
#twint -s "Berkshire hataway" --csv -o BH_tweets_during_war_part7.csv --since 2021-04-01 --until 2021-06-01

# %%
import pandas as pd
import sqlite3 as sql
#Merged parts of tweets about Berkshire hathaway before pandemic

BH_tweets_before_pandemic_part1 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_before_pandemic_part1.csv', sep = '\t')
BH_tweets_before_pandemic_part2 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_before_pandemic_part2.csv', sep = '\t')
BH_tweets_before_pandemic_part3 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_before_pandemic_part3.csv', sep = '\t')
BH_tweets_before_pandemic_part4 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_before_pandemic_part4.csv', sep = '\t')





con = sql.connect('example.db')
BH_tweets_before_pandemic_part1.to_sql('BH_tweets_before_pandemic_part1', con, if_exists='replace')
BH_tweets_before_pandemic_part2.to_sql('BH_tweets_before_pandemic_part2', con, if_exists='replace')
BH_tweets_before_pandemic_part3.to_sql('BH_tweets_before_pandemic_part3', con, if_exists='replace')
BH_tweets_before_pandemic_part4.to_sql('BH_tweets_before_pandemic_part4', con, if_exists='replace')

BH_tweets_before_pandemic = pd.read_sql("SELECT * FROM BH_tweets_before_pandemic_part1 UNION SELECT * FROM BH_tweets_before_pandemic_part2 UNION SELECT * FROM BH_tweets_before_pandemic_part3 UNION SELECT * FROM BH_tweets_before_pandemic_part4;", con)


BH_tweets_before_pandemic.to_sql('BH_tweets_before_pandemic', con, if_exists='replace', index = False)

BH_tweets_before_pandemic
# Out:
#        index                   id      conversation_id  \
# 0          0   947604334589763584   947604334589763584
# 1          0   980211275224502272   980211275224502272
# 2          0  1015169318764417024  1015169318764417024
# 3          0  1035675683450761217  1035675683450761217
# 4          1   947599778044510208   947599778044510208
# ...      ...                  ...                  ...
# 81422  29596   947671655190618112   947671655190618112
# 81423  29597   947670127272714240   947670127272714240
# 81424  29598   947641297774546944   947641297774546944
# 81425  29599   947625924266164226   947625924266164226
# 81426  29600   947624306443513857   947617497712340992
#
#                      created_at        date      time  timezone  \
# 0       2018-01-01 00:04:13 CET  2018-01-01  00:04:13       200
# 1      2018-04-01 00:32:34 CEST  2018-04-01  00:32:34       200
# 2      2018-07-06 11:43:21 CEST  2018-07-06  11:43:21       200
# ...

# %%
#Merged parts of tweets about Berkshire hathaway during pandemic

BH_tweets_during_pandemic_part1 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_pandemic_part1.csv', sep = '\t')
BH_tweets_during_pandemic_part2 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_pandemic_part2.csv', sep = '\t')
BH_tweets_during_pandemic_part3 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_pandemic_part3.csv', sep = '\t')
BH_tweets_during_pandemic_part4 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_pandemic_part4.csv', sep = '\t')

con = sql.connect('example.db')
BH_tweets_during_pandemic_part1.to_sql('BH_tweets_during_pandemic_part1', con, if_exists='replace')
BH_tweets_during_pandemic_part2.to_sql('BH_tweets_during_pandemic_part2', con, if_exists='replace')
BH_tweets_during_pandemic_part3.to_sql('BH_tweets_during_pandemic_part3', con, if_exists='replace')
BH_tweets_during_pandemic_part4.to_sql('BH_tweets_during_pandemic_part4', con, if_exists='replace')

BH_tweets_during_pandemic = pd.read_sql("SELECT * FROM BH_tweets_during_pandemic_part1 UNION SELECT * FROM BH_tweets_during_pandemic_part2 UNION SELECT * FROM BH_tweets_during_pandemic_part3 UNION SELECT * FROM BH_tweets_during_pandemic_part4;", con)


BH_tweets_during_pandemic.to_sql('BH_tweets_during_pandemic', con, if_exists='replace', index = False)

BH_tweets_during_pandemic
# Out:
#        index                   id      conversation_id  \
# 0          0  1212160894538522626  1212160894538522626
# 1          0  1245136282444947457  1245136282444947457
# 2          0  1278115609407094784  1278115609407094784
# 3          0  1311454882008891393  1311454882008891393
# 4          1  1212160711574601733  1151613069480615937
# ...      ...                  ...                  ...
# 66172  20949  1245167367195447298  1245140269252608001
# 66173  20950  1245164445564899334  1245164445564899334
# 66174  20951  1245149030709149698  1245149030709149698
# 66175  20952  1245142853640224769  1245137874519023616
# 66176  20953  1245138896004042754  1245138896004042754
#
#                      created_at        date      time  timezone  \
# 0       2020-01-01 00:57:32 CET  2020-01-01  00:57:32       200
# 1      2020-04-01 01:49:57 CEST  2020-04-01  01:49:57       200
# 2      2020-07-01 01:58:02 CEST  2020-07-01  01:58:02       200
# ...

# %%
#Merged parts of tweets about Berkshire hathaway during war

BH_tweets_during_war_part1 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part1.csv', sep = '\t')
BH_tweets_during_war_part2 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part2.csv', sep = '\t')
BH_tweets_during_war_part3 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part3.csv', sep = '\t')
BH_tweets_during_war_part4 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part4.csv', sep = '\t')
BH_tweets_during_war_part5 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part5.csv', sep = '\t')
BH_tweets_during_war_part6 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part6.csv', sep = '\t')
BH_tweets_during_war_part7 = pd.read_csv('C:/Users/ll/Desktop/dane/BH_tweets_during_war_part7.csv', sep = '\t')

con = sql.connect('example.db')
BH_tweets_during_war_part1.to_sql('BH_tweets_during_war_part1', con, if_exists='replace')
BH_tweets_during_war_part2.to_sql('BH_tweets_during_war_part2', con, if_exists='replace')
BH_tweets_during_war_part3.to_sql('BH_tweets_during_war_part3', con, if_exists='replace')
BH_tweets_during_war_part4.to_sql('BH_tweets_during_war_part4', con, if_exists='replace')
BH_tweets_during_war_part5.to_sql('BH_tweets_during_war_part5', con, if_exists='replace')
BH_tweets_during_war_part6.to_sql('BH_tweets_during_war_part6', con, if_exists='replace')
BH_tweets_during_war_part7.to_sql('BH_tweets_during_war_part7', con, if_exists='replace')

BH_tweets_during_war = pd.read_sql("SELECT * FROM BH_tweets_during_war_part1 UNION SELECT * FROM BH_tweets_during_war_part2 UNION SELECT * FROM BH_tweets_during_war_part3 UNION SELECT * FROM BH_tweets_during_war_part4 UNION SELECT * FROM BH_tweets_during_war_part5 UNION SELECT * FROM BH_tweets_during_war_part6 UNION SELECT * FROM BH_tweets_during_war_part7;", con)


BH_tweets_during_war.to_sql('BH_tweets_during_war', con, if_exists='replace', index = False)

BH_tweets_during_pandemic
# Out:
#        index                   id      conversation_id  \
# 0          0  1212160894538522626  1212160894538522626
# 1          0  1245136282444947457  1245136282444947457
# 2          0  1278115609407094784  1278115609407094784
# 3          0  1311454882008891393  1311454882008891393
# 4          1  1212160711574601733  1151613069480615937
# ...      ...                  ...                  ...
# 66172  20949  1245167367195447298  1245140269252608001
# 66173  20950  1245164445564899334  1245164445564899334
# 66174  20951  1245149030709149698  1245149030709149698
# 66175  20952  1245142853640224769  1245137874519023616
# 66176  20953  1245138896004042754  1245138896004042754
#
#                      created_at        date      time  timezone  \
# 0       2020-01-01 00:57:32 CET  2020-01-01  00:57:32       200
# 1      2020-04-01 01:49:57 CEST  2020-04-01  01:49:57       200
# 2      2020-07-01 01:58:02 CEST  2020-07-01  01:58:02       200
# ...
